# %%
# !nvidia-smi
# Out:
# Thu Sep 17 23:08:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q fastapi "uvicorn[standard]" pyngrok nest-asyncio

# %%
from pyngrok import ngrok

# Replace with your actual ngrok auth token
ngrok.set_auth_token("ng-3JTYeLhinuWvJNNJ0Yts4QJeMjo-g1-72jcM6pFC6kN1MnjYmyTr9xodRRR1fFoc")
